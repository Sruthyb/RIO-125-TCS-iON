# %% [markdown]
# <a href="https://colab.research.google.com/github/Sruthyb/intern/blob/main/TCS_internship.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Forecasting System - Project Demand of Products at a Retail Outlet Based on historical data

# %%
#importing necessary packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import itertools

import statsmodels.api as sm
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from statsmodels.tsa.statespace.sarimax import SARIMAX
#from pmdarima import auto_arima

from sklearn.metrics import mean_squared_error,mean_absolute_error
from statsmodels.tools.eval_measures import rmse

import warnings       
warnings.filterwarnings("ignore")
sns.set_style('darkgrid')
from google.colab import drive
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install --upgrade xlrd

# %%
#reading data to python environment
pd.set_option('display.max_columns', 9994)
df = pd.read_excel("/content/drive/My Drive/Colab Notebooks/TCS-intern/Sample - Superstore.xls")
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0        42420  South  FUR-BO-10001798        Furniture    Bookcases
# 1        42420  South  FUR-CH-10000454        Furniture       Chairs
# 2        90036   West  OFF-LA-10000240  Office Supplies       Labels
# 3        33311  South  FUR-TA-10000577        Furniture       Tables
# 4        33311  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
df.corr()['Sales']
# Out:
# Row ID        -0.001359
# Postal Code   -0.023854
# Sales          1.000000
# Quantity       0.200795
# Discount      -0.028190
# Profit         0.479064
# Name: Sales, dtype: float64

# %% [markdown]
# other Features have no correlation is observed with the sales feature.

# %% [markdown]
# ## Indexing time series data

# %%
df = df.set_index(['Order Date'])

# %%
df.index.min(), df.index.max()
# Out:
# (Timestamp('2014-01-03 00:00:00'), Timestamp('2017-12-30 00:00:00'))

# %% [markdown]
#  #### Note:
#  - The dataset used for this project is a superstore data from 2014 to 2018 containing 9994 entries and 21 features and this is a time series data.
#  - Dataset contains object, float and integer Data types and the date columns are already in datetime format.
#  - there is no feature having strong correlation with sales feature.
#  - For forecasting, we are using mainly the Sales Data with the order data of different product categories.

# %% [markdown]
# ## Visualising Data

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 15, 9
df['Sales'].plot();

# %% [markdown]
# ## Resampling Data

# %%
#monthly mean sales begin
mean_monthlysales = df.resample(rule='MS').mean()['Sales']
print(mean_monthlysales)
mean_monthlysales.plot(figsize=(15,5),c='green')
plt.show()
# Out:
# Order Date
# 2014-01-01    180.213861
# 2014-02-01     98.258522
# 2014-03-01    354.719803
# 2014-04-01    209.595148
# 2014-05-01    193.838418
# 2014-06-01    256.260204
# 2014-07-01    237.387364
# 2014-08-01    182.414827
# 2014-09-01    305.139369
# 2014-10-01    197.820082
# 2014-11-01    247.260115
# 2014-12-01    250.164103
# 2015-01-01    313.346131
# 2015-02-01    186.740797
# 2015-03-01    280.625014
# 2015-04-01    213.720053
# 2015-05-01    206.381414
# 2015-06-01    179.690522
# 2015-07-01    205.466607
# 2015-08-01    232.064982
# 2015-09-01    220.463884
# 2015-10-01    189.186286
# 2015-11-01    234.483221
# 2015-12-01    237.087092
# 2016-01-01    208.342596
# 2016-02-01    276.853193
# 2016-03-01    317.275307
# 2016-04-01    227.941406
# 2016-05-01    253.278791
# 2016-06-01    202.736352
# 2016-07-01    195.333149
# 2016-08-01    176.791899
# 2016-09-01    202.231474
# 2016-10-01    304.529311
# 2016-11-01    214.626935
# 2016-12-01    275.565463
# 2017-01-01    283.686284
# 2017-02-01    189.730219
# 2017-03-01    247.362827
# 2017-04-01    179.909045
# 2017-05-01    182.897150
# 2017-06-01    216.251942
# 2017-07-01    200.285027
# 2017-08-01    289.545358
# 2017-09-01    191.430614
# 2017-10-01    260.996387
# 2017-11-01    258.056264
# 2017-12-01    181.448742
# Freq: MS, Name: Sales, dtype: float64

# %% [markdown]
#  #### Note:
#  - Mean monthly sales is maximum in month march of year 2014.
#  - Also on month sep 2014, jan 2015, march 2016, oct 2016 shows higher sales.
#  - There is a huge dip in the graph during feb 2014 which shows least sales.

# %%
df.resample(rule='A').max()['Profit'].plot(kind='bar', figsize = (12,4))
plt.show()

# %% [markdown]
# ###### Note: maximum profit is observed in the year 2016 and least in year 2015.

# %%
#MAX MONTHLY SALES
df.resample(rule='M').max()['Sales'].plot(figsize= (15,5))
plt.show()

# %% [markdown]
# #### Note: Eventhough, Maximum sales observed to be in year 2014 profit is more on year 2016 as seen from above two graphs.

# %% [markdown]
# ## Data Pre-processing

# %%
#checking for unique values in columns
{column: len(df[column].unique()) for column in df.columns}
# Out:
# {'Category': 3,
#  'City': 531,
#  'Country': 1,
#  'Customer ID': 793,
#  'Customer Name': 793,
#  'Discount': 12,
#  'Order ID': 5009,
#  'Postal Code': 631,
#  'Product ID': 1862,
#  'Product Name': 1850,
#  'Profit': 7545,
#  'Quantity': 14,
#  'Region': 4,
#  'Row ID': 9994,
#  'Sales': 6144,
#  'Segment': 3,
#  'Ship Date': 1334,
#  'Ship Mode': 4,
#  'State': 49,
#  'Sub-Category': 17}

# %%
df = df.copy()
#dropping unnecessary columns    
df = df.drop(['Row ID','Country','Customer Name','Product Name','Order ID','Customer ID'],axis=1)

# %%
df.shape
# Out:
# (9994, 14)

# %%
#checking for missing values
df.isna().sum()
# Out:
# Ship Date       0
# Ship Mode       0
# Segment         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Product ID      0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# #### Note: The Dataset not containing any missing values.

# %%
#checking different categories in 'category' column
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
# Since dataset contain multiple categories of products we have to create seperate Dataframes for each category for analysis.

# %% [markdown]
# ### FURNITURE

# %%
#selecting rows where category is furniture
furniture_data = df.loc[df['Category'] == 'Furniture']
furniture_data
# Out:
#             Ship Date       Ship Mode      Segment             City  \
# Order Date
# 2016-11-08 2016-11-11    Second Class     Consumer        Henderson
# 2016-11-08 2016-11-11    Second Class     Consumer        Henderson
# 2015-10-11 2015-10-18  Standard Class     Consumer  Fort Lauderdale
# 2014-06-09 2014-06-14  Standard Class     Consumer      Los Angeles
# 2014-06-09 2014-06-14  Standard Class     Consumer      Los Angeles
# ...               ...             ...          ...              ...
# 2015-03-19 2015-03-22     First Class  Home Office          Houston
# 2016-12-05 2016-12-10    Second Class    Corporate           Newark
# 2015-09-06 2015-09-09    Second Class     Consumer        Lafayette
# 2014-01-21 2014-01-23    Second Class     Consumer            Miami
# 2017-02-26 2017-03-03  Standard Class     Consumer       Costa Mesa
#
#                  State  Postal Code   Region       Product ID   Category  \
# Order Date
# 2016-11-08    Kentucky        42420    South  FUR-BO-10001798  Furniture
# 2016-11-08    Kentucky        42420    South  FUR-CH-10000454  Furniture
# 2015-10-11     Florida        33311    South  FUR-TA-10000577  Furniture
# 2014-06-09  California        90032     West  FUR-FU-10001487  Furniture
# 2014-06-09  California        90032     West  FUR-TA-10001539  Furniture
# ...                ...          ...      ...              ...        ...
# 2015-03-19       Texas        77041  Central  FUR-BO-10004218  Furniture
# 2016-12-05    Delaware        19711     East  FUR-FU-10002671  Furniture
# 2015-09-06   Louisiana        70506    South  FUR-TA-10001039  Furniture
# 2014-01-21     Florida        33180    South  FUR-FU-10001889  Furniture
# 2017-02-26  California        92627     West  FUR-FU-10000747  Furniture
#
#            Sub-Category      Sales  Quantity  Discount    Profit
# Order Date
# 2016-11-08    Bookcases   261.9600         2      0.00   41.9136
# 2016-11-08       Chairs   731.9400         3      0.00  219.5820
# 2015-10-11       Tables   957.5775         5      0.45 -383.0310
# 2014-06-09  Furnishings    48.8600         7      0.00   14.1694
# 2014-06-09       Tables  1706.1840         9      0.20   85.3092
# ...                 ...        ...       ...       ...       ...
# 2015-03-19    Bookcases   383.4656         4      0.32  -67.6704
# 2016-12-05  Furnishings    13.4000         1      0.00    6.4320
# 2015-09-06       Tables    85.9800         1      0.00   22.3548
# 2014-01-21  Furnishings    25.2480         3      0.20    4.1028
# 2017-02-26  Furnishings    91.9600         2      0.00   15.6332
#
# [2121 rows x 14 columns]

# %%
col = ['Ship Date','Ship Mode','Segment','City','State','Postal Code','Region','Product ID','Category','Sub-Category','Quantity','Discount','Profit']
furniture_data.drop(col,axis=1, inplace=True)

# %%
furniture_data.head()
# Out:
#                 Sales
# Order Date
# 2016-11-08   261.9600
# 2016-11-08   731.9400
# 2015-10-11   957.5775
# 2014-06-09    48.8600
# 2014-06-09  1706.1840

# %%
#sorting by order date
furniture_data = furniture_data.sort_values('Order Date')
furniture_data
# Out:
#                Sales
# Order Date
# 2014-01-06  2573.820
# 2014-01-07    76.728
# 2014-01-10    51.940
# 2014-01-11     9.940
# 2014-01-13   545.940
# ...              ...
# 2017-12-29   258.750
# 2017-12-29  1207.840
# 2017-12-29   101.120
# 2017-12-29   300.980
# 2017-12-30   323.136
#
# [2121 rows x 1 columns]

# %%
furniture_data.describe()
# Out:
#              Sales
# count  2121.000000
# mean    349.834887
# std     503.179145
# min       1.892000
# 25%      47.040000
# 50%     182.220000
# 75%     435.168000
# max    4416.174000

# %%
furniture_data.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-07', '2014-01-10', '2014-01-11',
#                '2014-01-13', '2014-01-13', '2014-01-14', '2014-01-16',
#                '2014-01-19', '2014-01-20',
#                ...
#                '2017-12-28', '2017-12-28', '2017-12-28', '2017-12-29',
#                '2017-12-29', '2017-12-29', '2017-12-29', '2017-12-29',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=2121, freq=None)

# %%
#taking monthly mean sales of category furniture
y_furniture = furniture_data['Sales'].resample('MS').mean()

# %%
#observing mean monthly sales of furnitures
y_furniture.plot(figsize = (15,5))
plt.title('Mean Monthly Sales of Furniture items', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# Note: average sales is maximum at Jan 2015.

# %%
furniture_data.plot(figsize=(15,5))
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(y_furniture).set_title('Box Plot on sales of furniture items')
plt.show()

# %% [markdown]
# There is one outlier in the furniture data.

# %% [markdown]
# ### OFFICE SUPPLIES

# %%
office_supplies_data = df.loc[df['Category'] == 'Office Supplies']
office_supplies_data
# Out:
#             Ship Date       Ship Mode    Segment             City       State  \
# Order Date
# 2016-06-12 2016-06-16    Second Class  Corporate      Los Angeles  California
# 2015-10-11 2015-10-18  Standard Class   Consumer  Fort Lauderdale     Florida
# 2014-06-09 2014-06-14  Standard Class   Consumer      Los Angeles  California
# 2014-06-09 2014-06-14  Standard Class   Consumer      Los Angeles  California
# 2014-06-09 2014-06-14  Standard Class   Consumer      Los Angeles  California
# ...               ...             ...        ...              ...         ...
# 2016-09-22 2016-09-28  Standard Class   Consumer     Grand Rapids    Michigan
# 2015-05-17 2015-05-23  Standard Class   Consumer       Long Beach    New York
# 2015-05-17 2015-05-23  Standard Class   Consumer       Long Beach    New York
# 2017-02-26 2017-03-03  Standard Class   Consumer       Costa Mesa  California
# 2017-05-04 2017-05-09    Second Class   Consumer      Westminster  California
#
#             Postal Code   Region       Product ID         Category  \
# Order Date
# 2016-06-12        90036     West  OFF-LA-10000240  Office Supplies
# 2015-10-11        33311    South  OFF-ST-10000760  Office Supplies
# 2014-06-09        90032     West  OFF-AR-10002833  Office Supplies
# 2014-06-09        90032     West  OFF-BI-10003910  Office Supplies
# 2014-06-09        90032     West  OFF-AP-10002892  Office Supplies
# ...                 ...      ...              ...              ...
# 2016-09-22        49505  Central  OFF-PA-10002195  Office Supplies
# 2015-05-17        11561     East  OFF-LA-10003766  Office Supplies
# 2015-05-17        11561     East  OFF-SU-10000898  Office Supplies
# 2017-02-26        92627     West  OFF-PA-10004041  Office Supplies
# 2017-05-04        92683     West  OFF-AP-10002684  Office Supplies
#
#            Sub-Category    Sales  Quantity  Discount   Profit
# Order Date
# 2016-06-12       Labels   14.620         2       0.0   6.8714
# 2015-10-11      Storage   22.368         2       0.2   2.5164
# 2014-06-09          Art    7.280         4       0.0   1.9656
# 2014-06-09      Binders   18.504         3       0.2   5.7825
# 2014-06-09   Appliances  114.900         5       0.0  34.4700
# ...                 ...      ...       ...       ...      ...
# 2016-09-22        Paper   35.560         7       0.0  16.7132
# 2015-05-17       Labels   31.500        10       0.0  15.1200
# 2015-05-17     Supplies   55.600         4       0.0  16.1240
# 2017-02-26        Paper   29.600         4       0.0  13.3200
# 2017-05-04   Appliances  243.160         2       0.0  72.9480
#
# [6026 rows x 14 columns]

# %%
office_supplies_data.drop(col,axis=1, inplace=True)

# %%
office_supplies_data = office_supplies_data.sort_values('Order Date')
office_supplies_data.head()
# Out:
#               Sales
# Order Date
# 2014-01-03   16.448
# 2014-01-04  272.736
# 2014-01-04   11.784
# 2014-01-04    3.540
# 2014-01-05   19.536

# %%
office_supplies_data.describe()
# Out:
#              Sales
# count  6026.000000
# mean    119.324101
# std     382.182228
# min       0.444000
# 25%      11.760000
# 50%      27.418000
# 75%      79.920000
# max    9892.740000

# %%
office_supplies_data.index
# Out:
# DatetimeIndex(['2014-01-03', '2014-01-04', '2014-01-04', '2014-01-04',
#                '2014-01-05', '2014-01-06', '2014-01-06', '2014-01-06',
#                '2014-01-06', '2014-01-06',
#                ...
#                '2017-12-29', '2017-12-29', '2017-12-29', '2017-12-29',
#                '2017-12-29', '2017-12-30', '2017-12-30', '2017-12-30',
#                '2017-12-30', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=6026, freq=None)

# %%
y_office = office_supplies_data['Sales'].resample('MS').mean()

# %%
y_office.plot(figsize = (15,5))
plt.title('Mean Monthly Sales of office items', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# Sales for office supplies shows maximum at start of year between feb to april and minimum at end of year.

# %%
office_supplies_data.plot(figsize=(15,5), c = 'grey')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(y_office).set_title('Box Plot on sales of office items')
plt.show()

# %% [markdown]
# there are three outliers in the office items data.

# %% [markdown]
# ## Technology items

# %%
technology_data = df.loc[df['Category'] == 'Technology']
technology_data
# Out:
#             Ship Date       Ship Mode    Segment           City       State  \
# Order Date
# 2014-06-09 2014-06-14  Standard Class   Consumer    Los Angeles  California
# 2014-06-09 2014-06-14  Standard Class   Consumer    Los Angeles  California
# 2014-08-27 2014-09-01    Second Class   Consumer  San Francisco  California
# 2016-01-16 2016-01-20    Second Class   Consumer    Los Angeles  California
# 2016-12-08 2016-12-10     First Class  Corporate     Richardson       Texas
# ...               ...             ...        ...            ...         ...
# 2016-09-22 2016-09-28  Standard Class   Consumer   Grand Rapids    Michigan
# 2016-09-29 2016-10-03  Standard Class   Consumer    Los Angeles  California
# 2017-11-17 2017-11-21  Standard Class  Corporate         Athens     Georgia
# 2017-11-17 2017-11-21  Standard Class  Corporate         Athens     Georgia
# 2017-02-26 2017-03-03  Standard Class   Consumer     Costa Mesa  California
#
#             Postal Code   Region       Product ID    Category Sub-Category  \
# Order Date
# 2014-06-09        90032     West  TEC-PH-10002275  Technology       Phones
# 2014-06-09        90032     West  TEC-PH-10002033  Technology       Phones
# 2014-08-27        94109     West  TEC-PH-10001949  Technology       Phones
# 2016-01-16        90049     West  TEC-AC-10003027  Technology  Accessories
# 2016-12-08        75080  Central  TEC-PH-10004977  Technology       Phones
# ...                 ...      ...              ...         ...          ...
# 2016-09-22        49505  Central  TEC-PH-10001305  Technology       Phones
# 2016-09-29        90008     West  TEC-AC-10003399  Technology  Accessories
# 2017-11-17        30605    South  TEC-AC-10001539  Technology  Accessories
# 2017-11-17        30605    South  TEC-PH-10004006  Technology       Phones
# 2017-02-26        92627     West  TEC-PH-10003645  Technology       Phones
#
#                Sales  Quantity  Discount    Profit
# Order Date
# 2014-06-09   907.152         6       0.2   90.7152
# 2014-06-09   911.424         4       0.2   68.3568
# 2014-08-27   213.480         3       0.2   16.0110
# 2016-01-16    90.570         3       0.0   11.7741
# 2016-12-08  1097.544         7       0.2  123.4737
# ...              ...       ...       ...       ...
# 2016-09-22    97.980         2       0.0   27.4344
# 2016-09-29    36.240         1       0.0   15.2208
# 2017-11-17    79.990         1       0.0   28.7964
# 2017-11-17   206.100         5       0.0   55.6470
# 2017-02-26   258.576         2       0.2   19.3932
#
# [1847 rows x 14 columns]

# %%
technology_data.drop(col,axis=1, inplace=True)

# %%
technology_data = technology_data.sort_values('Order Date')

# %%
technology_data.describe()
# Out:
#               Sales
# count   1847.000000
# mean     452.709276
# std     1108.655848
# min        0.990000
# 25%       68.016000
# 50%      166.160000
# 75%      448.534000
# max    22638.480000

# %%
technology_data.index
# Out:
# DatetimeIndex(['2014-01-06', '2014-01-06', '2014-01-09', '2014-01-13',
#                '2014-01-15', '2014-01-16', '2014-01-20', '2014-01-26',
#                '2014-01-26', '2014-02-01',
#                ...
#                '2017-12-24', '2017-12-24', '2017-12-25', '2017-12-25',
#                '2017-12-25', '2017-12-25', '2017-12-27', '2017-12-28',
#                '2017-12-29', '2017-12-30'],
#               dtype='datetime64[ns]', name='Order Date', length=1847, freq=None)

# %%
technology_data.index.min(), technology_data.index.max()
# Out:
# (Timestamp('2014-01-06 00:00:00'), Timestamp('2017-12-30 00:00:00'))

# %%
y_technology = technology_data['Sales'].resample('MS').mean()

# %%
y_technology.plot(figsize = (15,5))
plt.title('Mean Monthly Sales of Technology items', fontsize=16, fontweight='bold')
plt.show()

# %% [markdown]
# Technology items have highest sales in march 2014 and also in oct-nov of 2016.

# %%
technology_data.plot(figsize=(15,5), c = 'green', legend = True)
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
sns.boxplot(y_technology).set_title('Box Plot on technology items')
plt.show()

# %% [markdown]
# there are two outliers in the technology data.

# %% [markdown]
# ## Seasonal Decomposition of each category

# %% [markdown]
# ### Furniture items

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 9
decomposition = sm.tsa.seasonal_decompose(y_furniture, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
#  - Decreasing trend is observed for the sales of furniture after 2015.

# %% [markdown]
# ### Office items

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 9
decomposition = sm.tsa.seasonal_decompose(y_office, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# From the trend graph,there is a rise in curve and reaches a maximum at middle of 2014 after that there is huge fall in sales from 2015 to 2016. Then it gradually rises reach a maximum at beginning of 2016 and repeats.

# %% [markdown]
# ### Technology

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 9
decomposition = sm.tsa.seasonal_decompose(y_technology, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# huge rise in sales is observed from middle of 2015 to first half of 2016 after that falls.

# %% [markdown]
# ## Test for stationarity

# %%
#Augmented dickey-fuller test
#H0 : data is non stationary (unit root =1)
#H1 : data is stationery (unit root <1)

def adfuller_test(series):
    result = adfuller(series)
    labels = ['ADF test statistic', 'p-value', 'Number of observations used', '#lags used']
    for value, label in zip(result, labels):
        print(label+' : '+str(value))
        
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
adfuller_test(y_furniture)
# Out:
# ADF test statistic : -6.962405221214861
# p-value : 9.093398510006677e-10
# Number of observations used : 0
# #lags used : 47
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
adfuller_test(y_office)
# Out:
# ADF test statistic : -6.100365254423857
# p-value : 9.869101392257422e-08
# Number of observations used : 0
# #lags used : 47
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %%
adfuller_test(y_technology)
# Out:
# ADF test statistic : -7.8725670697716446
# p-value : 4.94020681035215e-12
# Number of observations used : 0
# #lags used : 47
# strong evidence against the null hypothesis, reject the null hypothesis. Data has no unit root and is stationary

# %% [markdown]
# #### Findings:
#  - The p-value<0.05, so rejecting null hypothesis and assume a stationery datasets.
#  - Here the differencing value (d) is zero.

# %% [markdown]
# ## Autocorrelation and Partial Autocorrelation plots

# %% [markdown]
# ACF measures correlation between the time series with a lagged version itself and PACF similiar to ACF but after eliminating the variations.

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %% [markdown]
# #### Furniture

# %%
fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
sm.graphics.tsa.plot_pacf(y_furniture,lags=23,method="ols",ax=axes[0])
sm.graphics.tsa.plot_acf(y_furniture, lags=23,ax=axes[1])
plt.show()

# %% [markdown]
# #### Office supplies

# %%
fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
sm.graphics.tsa.plot_pacf(y_furniture,lags=23,method="ols",ax=axes[0])
sm.graphics.tsa.plot_acf(y_furniture, lags=23,ax=axes[1])
plt.show()

# %% [markdown]
# #### Technology

# %%
fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
sm.graphics.tsa.plot_pacf(y_technology,lags=23,method="ols",ax=axes[0])
sm.graphics.tsa.plot_acf(y_technology, lags=23,ax=axes[1])
plt.show()

# %% [markdown]
# ## Parameter selection

# %% [markdown]
# Parameters of the ARIMA model are defined by
#  - AR(p)-lag order
#  - I(d) -degree of difference
#  - MA(q) - order of moving average
#
# SARIMAX an extension of ARIMA supports time series data with a seasonal component. it is denoted by order (p,d,q)(P,D,Q)m.
#  - P - Seasonal regression
#  - D - differencing
#  - Q - moving average coefficients
#  - m - no.of datapoints in each seasonal cycle

# %%
# Defining p,d and q parameters to take any value between 0 and 2
p = d = q = range(0, 2)

# Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, d and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA are as follows:-')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA are as follows:-
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# ## Furniture

# %% [markdown]
# ### Grid search

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            model = sm.tsa.statespace.SARIMAX(y_furniture,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = model.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:688.3112416991725
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1565.977281468862
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:426.2046489859171
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:272.091984762829
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:452.8238602501691
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1571.0201242562
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:295.44645647223496
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:274.09198456327965
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:641.1240680665804
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2671.215658209401
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:416.5496453364607
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:262.5230517047702
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:455.1588765434245
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2430.5547358352637
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:297.44640662503576
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:264.5230013128144
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:580.638926970597
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1382.1444044419063
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:433.3552136704902
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:274.1069295746763
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:437.46040107889746
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1382.8617670049148
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:294.1158452476944
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:276.10533141664416
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:538.8964721447173
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1637.364961276864
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:412.8726989905025
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:251.2470775508363
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:419.1839792724932
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1931.5076639925278
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:273.40324546363286
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:253.2196476461964
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:592.7661498749849
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1272.2880166707594
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:427.7241159738326
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:273.5820684371087
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:420.4114538992038
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1367.2950381120672
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:273.5840395565933
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:275.5784303961359
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:553.2719417804623
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1621.427740096201
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:418.5261783088981
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:263.82167771134436
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:422.4003583321996
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1679.6265963338494
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:275.47757405309034
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:265.82121058834826
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:566.5211872508684
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1306.4963993078795
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:430.3305770817937
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:273.43213783258983
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:397.3668981651504
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1008.9055903822015
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:273.4415398792927
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:275.41278577499816
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:540.6257368397357
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:2319.7565218969626
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:414.7726173043228
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:252.6613432747479
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:391.83032555553996
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1564.4436210912154
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:263.93710843812755
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:254.64207132003688

# %% [markdown]
# AIC is an estimates relative quality of model and desired result is to fing lowest possible AIC score.
# The (p,d,q)(P,D,Q,m) order (0, 1, 1)(0, 1, 1, 12) have lower AIC value of 251.2470.

# %%
#fitting ARIMA model with best parameters
model = sm.tsa.statespace.SARIMAX(y_furniture,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                #enforce_stationarity=False,
                                enforce_invertibility=False)

results = model.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.0000   1892.758     -0.001      1.000   -3710.737    3708.737
# ma.S.L12      -1.0000   1892.824     -0.001      1.000   -3710.867    3708.866
# sigma2      7504.4474      0.180   4.17e+04      0.000    7504.095    7504.800
# ==============================================================================

# %% [markdown]
# ### Model diagnosis

# %%
results.plot_diagnostics(figsize=(18, 12))
plt.show()

# %% [markdown]
# ##### Note:
# From above plots,it is clear that the residuals are almost normally distributed and uncorrelated.

# %% [markdown]
# ## Visualising Forecasts

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = y_furniture['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
plt.title('Forecast of Furniture items', fontsize=16, fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y_furniture['2017-01-01':]

mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Mean Squared Error of our forecasts is 7555.04
# The Root Mean Squared Error of our forecasts is 86.92

# %%
# Get forecast 100 steps ahead in future
pred = results.get_forecast(steps=100)

# Get confidence intervals of forecasts
pred_ci = pred.conf_int()

ax = y_furniture.plot(label='observed', figsize=(15, 8))

pred.predicted_mean.plot(ax=ax, label='forecast')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], alpha=0.25)
plt.title('Forecast of Furniture items', fontsize=16, fontweight='bold')
ax.set_xlabel('year')
ax.set_ylabel('Occupancy')

plt.legend()
plt.show()

# %% [markdown]
# Plot shows a decreasing trend of sales of furniture items.

# %% [markdown]
# ## office supplies

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y_office,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:589.5002315061224
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1347.4267897981113
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:383.41755111407554
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:248.8928413116318
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:394.83867919808836
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1348.9258329412073
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:260.5044719309093
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:250.10262158195803
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:545.8315751699361
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2552.5155905373776
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:371.8194830276595
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:240.39856988639355
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:396.4373424315812
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2337.8547617140594
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:262.173516381938
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:242.26144570286047
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:496.8049609774628
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1183.5722634375454
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:391.413698403584
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:251.89413914217724
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:378.31299876316575
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1381.8979574422835
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:262.696974030596
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:252.1199575319309
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:466.0870809627708
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:2000.496270922089
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:363.8692923372037
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:231.55283799226888
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:363.34137211247486
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1324.7706045438601
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:253.95620060364084
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:233.55283788676596
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:507.92776839081154
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1501.7183659722507
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:385.35306504962415
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:250.6117598219319
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:379.4123664160901
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:994.2763468361693
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:251.60541618302221
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:251.96926521849682
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:478.4618435487694
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:1658.3717744983207
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:373.3236002293726
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:242.08090942751113
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:366.76767789204484
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1351.6784544792245
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:253.20920156285823
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:243.95354216960374
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:488.2907058342702
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1239.0986256091403
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:385.4021908074264
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:250.8678010477453
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:363.25413442592486
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1243.5908314353587
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:251.5208030905488
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:251.69840717484445
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:467.414931585739
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1493.6364980303254
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:365.7158294572241
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:233.53069429554125
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:354.3500940662214
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1394.639134073216
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:246.47966619978487
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:235.53068980338287

# %% [markdown]
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:231.55283799226888 have lower AIC value

# %%
model = sm.tsa.statespace.SARIMAX(y_office,
                                order=(0, 1, 1),
                                seasonal_order=(0, 1, 1, 12),
                                #enforce_stationarity=False,
                                enforce_invertibility=False)
#fitting model
results = model.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -1.0000   2057.653     -0.000      1.000   -4033.926    4031.926
# ma.S.L12      -0.5111      0.541     -0.945      0.345      -1.571       0.549
# sigma2      2634.0485   5.42e+06      0.000      1.000   -1.06e+07    1.06e+07
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %% [markdown]
# Here residuals are near normally distributed from top right and botton left plots and the correlation plot shows uncorrelated.

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = y_office['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
plt.title('Forecast of Sales for Office items', fontsize=16, fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('office Sales')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y_office['2017-01-01':]

mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Mean Squared Error of our forecasts is 2969.8
# The Root Mean Squared Error of our forecasts is 54.5

# %%
# Get forecast 100 steps ahead in future
pred_uc = results.get_forecast(steps=100)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

ax = y_office.plot(label='observed', figsize=(15, 8))

pred_uc.predicted_mean.plot(ax=ax, label='forecast')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
plt.title('Sales forecast of Office items', fontsize=16, fontweight='bold')
ax.set_xlabel('Year')
ax.set_ylabel('Occupancy')

plt.legend()
plt.show()

# %% [markdown]
# ## Technology

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y_technology,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)

            results = mod.fit()

            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:721.5688506163442
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1487.6419240338735
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:506.0787430128274
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:322.98754525549793
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:514.1576203103061
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1493.5436371349388
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:337.72306528701387
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:324.3265655019672
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:683.3203705205927
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2654.197749724426
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:494.63999626653646
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:305.7104828501362
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:514.2823881454683
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2674.9444607170085
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:336.08723533603455
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:306.6135534234986
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:668.3045721205369
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1540.7215342379855
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:515.904456199697
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:326.9541738301147
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:489.2638159231583
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1290.2068990355617
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:345.5369970527209
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:327.6514374906651
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:602.2471142494586
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:1079.7407936966354
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:473.92858634471133
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:294.6191233224847
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:468.51194673014254
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:1555.9001209421122
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:328.7313274572616
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:294.78717047400147
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:678.559605909867
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1506.7974302856287
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:508.07557950382954
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:323.1943985904043
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:488.7903320065973
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1374.34909567969
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:323.39300431518353
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:324.28682774539715
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:637.620262169018
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:2654.068143308505
# ARIMA(1, 0, 1)x(0, 1, 0, 12)12 - AIC:496.53314900866445
# ARIMA(1, 0, 1)x(0, 1, 1, 12)12 - AIC:305.7943036004784
# ARIMA(1, 0, 1)x(1, 0, 0, 12)12 - AIC:470.5579322937507
# ARIMA(1, 0, 1)x(1, 0, 1, 12)12 - AIC:1014.4091583950969
# ARIMA(1, 0, 1)x(1, 1, 0, 12)12 - AIC:326.95357727431406
# ARIMA(1, 0, 1)x(1, 1, 1, 12)12 - AIC:308.34899328104626
# ARIMA(1, 1, 0)x(0, 0, 0, 12)12 - AIC:655.6256841888278
# ARIMA(1, 1, 0)x(0, 0, 1, 12)12 - AIC:1581.550492571856
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:510.3391832281161
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:320.0578936380402
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:468.64672617724875
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1321.42158515731
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:321.3175159212054
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:322.0826128013723
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:603.2216368792657
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:972.9340036720007
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:475.81837830493606
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:296.0792680455173
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:457.28981452707797
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:2568.8635918717946
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:311.0634931173731
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:294.1604201223416

# %% [markdown]
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:294.1604201223416 have lower AIC value.

# %%
model = sm.tsa.statespace.SARIMAX(y_technology,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                #enforce_stationarity=False,
                                enforce_invertibility=False)

results = model.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2597      0.235     -1.103      0.270      -0.721       0.202
# ma.L1         -1.0000      0.550     -1.817      0.069      -2.079       0.079
# ar.S.L12      -0.3489      0.323     -1.081      0.280      -0.981       0.284
# ma.S.L12      -0.6468      0.787     -0.822      0.411      -2.189       0.895
# sigma2       5.38e+04   1.02e-05   5.26e+09      0.000    5.38e+04    5.38e+04
# ==============================================================================

# %%
results.plot_diagnostics(figsize=(18, 12))
plt.show()

# %% [markdown]
# Top right plot shows a normally distributed curve with zero mean and correlation graph shows uncorrelation.

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = y_technology['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
plt.title('Sales Forecast of Technology items', fontsize=16, fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('technology Sales')
plt.legend()

plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y_technology['2017-01-01':]

mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Mean Squared Error of our forecasts is 19069.96
# The Root Mean Squared Error of our forecasts is 138.09

# %%
# Get forecast 100 steps ahead in future
pred_uc = results.get_forecast(steps=100)

# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

ax = y_technology.plot(label='observed', figsize=(15, 8))

pred_uc.predicted_mean.plot(ax=ax, label='forecast')

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
plt.title('Sales  Forecast of Technology items', fontsize=16, fontweight='bold')
ax.set_xlabel('Year')
ax.set_ylabel('Occupancy')

plt.legend()
plt.show()

# %% [markdown]
# Increasing trend is observed from forecast for the sales of Technology products.

# %% [markdown]
# ### Comparing categories

# %%
furniture_data.shape, office_supplies_data.shape, technology_data.shape
# Out:
# ((2121, 1), (6026, 1), (1847, 1))

# %%
#furniture_data.drop(col, axis=1, inplace=True)
#office_supplies_data.drop(col, axis=1, inplace=True)
#technology_data(col, axis=1, inplace=True)

# %%
furniture_data = furniture_data.sort_values('Order Date')
office_supplies_data = office_supplies_data.sort_values('Order Date')
technology_data = technology_data.sort_values('Order Date')

furniture_data = furniture_data.groupby('Order Date')['Sales'].sum().reset_index()
office_supplies_data= office_supplies_data.groupby('Order Date')['Sales'].sum().reset_index()
technology_data = technology_data.groupby('Order Date')['Sales'].sum().reset_index()

furniture_data = furniture_data.set_index('Order Date')
office_supplies_data = office_supplies_data.set_index('Order Date')
technology_data = technology_data.set_index('Order Date')

y_furniture = furniture_data['Sales'].resample('MS').mean()
y_office = office_supplies_data['Sales'].resample('MS').mean()
y_technology = technology_data['Sales'].resample('MS').mean()

# %%
furniture = pd.DataFrame({'Order Date': y_furniture.index , 'Sales':y_furniture.values})
furniture.head()
# Out:
#   Order Date       Sales
# 0 2014-01-01  480.194231
# 1 2014-02-01  367.931600
# 2 2014-03-01  857.291529
# 3 2014-04-01  567.488357
# 4 2014-05-01  432.049188

# %%
office = pd.DataFrame({'Order Date': y_office.index , 'Sales':y_office.values})
office.head()
# Out:
#   Order Date       Sales
# 0 2014-01-01  285.357647
# 1 2014-02-01   63.042588
# 2 2014-03-01  391.176318
# 3 2014-04-01  464.794750
# 4 2014-05-01  324.346545

# %%
technology = pd.DataFrame({'Order Date': y_technology.index , 'Sales':y_technology.values})
technology.head()
# Out:
#   Order Date        Sales
# 0 2014-01-01   449.041429
# 1 2014-02-01   229.787143
# 2 2014-03-01  2031.948375
# 3 2014-04-01   613.028933
# 4 2014-05-01   564.698588

# %%
store = pd.merge(furniture,office, how='inner', on='Order Date')
store.rename(columns={'Sales_x': 'furniture_sales', 'Sales_y': 'office_sales', 'Sales_z': 'technology_sales'}, inplace=True)
store.head()
# Out:
#   Order Date  furniture_sales  office_sales
# 0 2014-01-01       480.194231    285.357647
# 1 2014-02-01       367.931600     63.042588
# 2 2014-03-01       857.291529    391.176318
# 3 2014-04-01       567.488357    464.794750
# 4 2014-05-01       432.049188    324.346545

# %%
store_office_furniture_technology = technology.merge(store, how='inner', on='Order Date')
store_office_furniture_technology.rename(columns={'Sales': 'technology_sales', 'Sales_x':'furniture_sales','Sales_y':'office_sales'},inplace=True)
store_office_furniture_technology
# Out:
#    Order Date  technology_sales  furniture_sales  office_sales
# 0  2014-01-01        449.041429       480.194231    285.357647
# 1  2014-02-01        229.787143       367.931600     63.042588
# 2  2014-03-01       2031.948375       857.291529    391.176318
# 3  2014-04-01        613.028933       567.488357    464.794750
# 4  2014-05-01        564.698588       432.049188    324.346545
# 5  2014-06-01        766.905909       695.059242    588.774409
# 6  2014-07-01        533.608933       601.169500    756.060400
# 7  2014-08-01        708.435385       457.521656    541.879143
# 8  2014-09-01       2035.838133       992.353367   1015.677704
# 9  2014-10-01        596.900900       769.015437    267.078815
# 10 2014-11-01       1208.056320       980.221486    959.372714
# 11 2014-12-01       1160.732889      1532.298325    692.556231
# 12 2015-01-01        925.070800       978.328467    129.198571
# 13 2015-02-01        431.121250       522.395667    335.504188
# 14 2015-03-01        574.662333       781.236437    690.545522
# 15 2015-04-01        697.559500       805.822962    502.342320
# 16 2015-05-01        831.642857       624.996700    364.549440
# 17 2015-06-01        429.024400       428.565500    560.407737
# 18 2015-07-01        691.397733       719.706316    205.214739
# 19 2015-08-01       1108.902286       602.412012    558.814667
# 20 2015-09-01        950.856400      1382.790684    772.230680
# 21 2015-10-01        594.716111       632.980184    361.392083
# 22 2015-11-01       1037.982652      1286.701354    757.790357
# 23 2015-12-01       1619.637636      1049.355418    540.055800
# 24 2016-01-01        374.671067       508.182867    331.230125
# 25 2016-02-01       1225.891400       356.868273    357.597368
# 26 2016-03-01       1135.150105       609.575810    693.877240
# 27 2016-04-01        875.911882       695.373158    462.932478
# 28 2016-05-01       1601.816167       687.265227    449.489724
# 29 2016-06-01       1023.259500       816.910750    436.072400
# 30 2016-07-01        829.312500       768.736412    587.474727
# 31 2016-08-01        483.620100       734.307782    344.605385
# 32 2016-09-01       1144.170300      1135.953371    830.847786
# 33 2016-10-01       1970.835875       624.872474    678.408083
# 34 2016-11-01       1085.642360      1271.345152    787.972231
# 35 2016-12-01        970.554870      1410.719808   1357.055929
# 36 2017-01-01       1195.218071       397.602133    967.013136
# 37 2017-02-01        430.501714       528.179800    389.882737
# 38 2017-03-01       1392.859250       544.672240    538.899481
# 39 2017-04-01        825.559133       453.297905    558.229296
# 40 2017-05-01        678.329400       678.302328    508.776444
# 41 2017-06-01        853.055000       826.460291    650.463038
# 42 2017-07-01       1054.996636       562.524857    393.902615
# 43 2017-08-01        978.842333       857.881889   1156.148154
# 44 2017-09-01       1077.704120      1209.508583   1139.137250
# 45 2017-10-01       1493.439227       875.362728    886.045846
# 46 2017-11-01       1996.750920      1277.817759   1124.012036
# 47 2017-12-01        955.865652      1256.298672   1049.549724

# %%
sns.set(font_scale=1)
plt.figure(figsize=(20,8))
plt.plot(store_office_furniture_technology['Order Date'],store_office_furniture_technology['furniture_sales'],'p-',label='furniture')
plt.plot(store_office_furniture_technology['Order Date'],store_office_furniture_technology['office_sales'],'g-',label='office supplies')
plt.plot(store_office_furniture_technology['Order Date'],store_office_furniture_technology['technology_sales'],'r-', label='technology')
plt.xlabel('Date',fontsize=14,fontweight='bold')
plt.ylabel('Sales', fontsize = 14,fontweight='bold')
plt.title('Sales Data', fontsize=16, fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# #### Findings:
# - from above plot, it is clear that technology items are most selling item compare to other categories and sales of office supplies is least.
#
# - sales of technology items is more than 2000 in the year 2014 but after that sales is declining in 2015.
#
# - Sales of furniture items shows a maximum at the end of year 2014 and a similiar rise occurs in second half of 2015 and 2016.
#
# - office supplies has maximum sales at the end of 2016.

# %% [markdown]
# ### comparing sales of different categories

# %% [markdown]
# ### a) Furniture vs office items

# %%
store.head()
# Out:
#   Order Date  furniture_sales  office_sales
# 0 2014-01-01       480.194231    285.357647
# 1 2014-02-01       367.931600     63.042588
# 2 2014-03-01       857.291529    391.176318
# 3 2014-04-01       567.488357    464.794750
# 4 2014-05-01       432.049188    324.346545

# %%
plt.figure(figsize=(20,8))

plt.plot(store['Order Date'],store['furniture_sales'],'p-',label='furniture')
plt.plot(store['Order Date'],store['office_sales'],'g-',label='office supplies')

plt.xlabel('Date',fontsize=14,fontweight='bold')
plt.ylabel('Sales', fontsize = 14,fontweight='bold')
plt.title('Sales of Furniture and Office items', fontsize=16, fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# ### b) Furniture vs Technology items sales

# %%
store_furniture_technology = pd.merge(furniture,technology, how='inner', on='Order Date')
store_furniture_technology.rename(columns={'Sales_x': 'furniture_sales', 'Sales_y': 'technology_sales'}, inplace=True)
store_furniture_technology.head()
# Out:
#   Order Date  furniture_sales  technology_sales
# 0 2014-01-01       480.194231        449.041429
# 1 2014-02-01       367.931600        229.787143
# 2 2014-03-01       857.291529       2031.948375
# 3 2014-04-01       567.488357        613.028933
# 4 2014-05-01       432.049188        564.698588

# %%
plt.figure(figsize=(20,8))
plt.plot(store_furniture_technology ['Order Date'],store_furniture_technology ['furniture_sales'],'p-',label='furniture')
plt.plot(store_furniture_technology ['Order Date'],store_furniture_technology ['technology_sales'],'r-', label='technology')
plt.xlabel('Date',fontsize=14,fontweight='bold')
plt.ylabel('Sales', fontsize = 14,fontweight='bold')
plt.title('Sales of Furniture and Technology Items', fontsize=16, fontweight='bold')
plt.legend()
plt.show()

# %% [markdown]
# ### c) office items vs technology sales

# %%
store_office_technology = pd.merge(office,technology, how='inner', on='Order Date')
store_office_technology.rename(columns={'Sales_x': 'office_sales', 'Sales_y': 'technology_sales'}, inplace=True)
store_office_technology.head()
# Out:
#   Order Date  office_sales  technology_sales
# 0 2014-01-01    285.357647        449.041429
# 1 2014-02-01     63.042588        229.787143
# 2 2014-03-01    391.176318       2031.948375
# 3 2014-04-01    464.794750        613.028933
# 4 2014-05-01    324.346545        564.698588

# %%
plt.figure(figsize=(20,8))
plt.plot(store_office_technology ['Order Date'],store_office_technology ['office_sales'],'p-',label='office supplies')
plt.plot(store_office_technology ['Order Date'],store_office_technology ['technology_sales'],'r-', label='technology')
plt.xlabel('Date',fontsize=14,fontweight='bold')
plt.ylabel('Sales', fontsize = 14,fontweight='bold')
plt.title('Sales of Office and Technology Items', fontsize=16, fontweight='bold')
plt.legend()
plt.show()

# %%
#!pip install Prophet

# %%
from prophet import Prophet

# %%
y_furniture_df = y_furniture.to_frame()
y_furniture_df['ds'] = y_furniture_df.index
y_furniture_df.columns = ['y','ds']
y_furniture_df
# Out:
#                       y         ds
# Order Date
# 2014-01-01   480.194231 2014-01-01
# 2014-02-01   367.931600 2014-02-01
# 2014-03-01   857.291529 2014-03-01
# 2014-04-01   567.488357 2014-04-01
# 2014-05-01   432.049188 2014-05-01
# 2014-06-01   695.059242 2014-06-01
# 2014-07-01   601.169500 2014-07-01
# 2014-08-01   457.521656 2014-08-01
# 2014-09-01   992.353367 2014-09-01
# 2014-10-01   769.015437 2014-10-01
# 2014-11-01   980.221486 2014-11-01
# 2014-12-01  1532.298325 2014-12-01
# 2015-01-01   978.328467 2015-01-01
# 2015-02-01   522.395667 2015-02-01
# 2015-03-01   781.236437 2015-03-01
# 2015-04-01   805.822962 2015-04-01
# 2015-05-01   624.996700 2015-05-01
# 2015-06-01   428.565500 2015-06-01
# 2015-07-01   719.706316 2015-07-01
# 2015-08-01   602.412012 2015-08-01
# 2015-09-01  1382.790684 2015-09-01
# 2015-10-01   632.980184 2015-10-01
# 2015-11-01  1286.701354 2015-11-01
# 2015-12-01  1049.355418 2015-12-01
# 2016-01-01   508.182867 2016-01-01
# 2016-02-01   356.868273 2016-02-01
# 2016-03-01   609.575810 2016-03-01
# 2016-04-01   695.373158 2016-04-01
# 2016-05-01   687.265227 2016-05-01
# 2016-06-01   816.910750 2016-06-01
# 2016-07-01   768.736412 2016-07-01
# 2016-08-01   734.307782 2016-08-01
# 2016-09-01  1135.953371 2016-09-01
# 2016-10-01   624.872474 2016-10-01
# 2016-11-01  1271.345152 2016-11-01
# 2016-12-01  1410.719808 2016-12-01
# 2017-01-01   397.602133 2017-01-01
# 2017-02-01   528.179800 2017-02-01
# 2017-03-01   544.672240 2017-03-01
# 2017-04-01   453.297905 2017-04-01
# 2017-05-01   678.302328 2017-05-01
# 2017-06-01   826.460291 2017-06-01
# 2017-07-01   562.524857 2017-07-01
# 2017-08-01   857.881889 2017-08-01
# 2017-09-01  1209.508583 2017-09-01
# 2017-10-01   875.362728 2017-10-01
# 2017-11-01  1277.817759 2017-11-01
# 2017-12-01  1256.298672 2017-12-01

# %%
m_furniture = Prophet()

m_furniture.fit(y_furniture_df)

future_furniture = m_furniture.make_future_dataframe(periods=24,freq='MS')

future_furniture
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#            ds
# 0  2014-01-01
# 1  2014-02-01
# 2  2014-03-01
# 3  2014-04-01
# 4  2014-05-01
# ..        ...
# 67 2019-08-01
# 68 2019-09-01
# 69 2019-10-01
# 70 2019-11-01
# 71 2019-12-01
#
# [72 rows x 1 columns]

# %%
forecast_furniture = m_furniture.predict(future_furniture)
forecast_furniture
# Out:
#            ds       trend   yhat_lower   yhat_upper  trend_lower  trend_upper  \
# 0  2014-01-01  726.057713   364.897149   695.484380   726.057713   726.057713
# 1  2014-02-01  727.494023   294.763073   606.769829   727.494023   727.494023
# 2  2014-03-01  728.791335   546.785602   869.698490   728.791335   728.791335
# 3  2014-04-01  730.227645   469.492154   788.782127   730.227645   730.227645
# 4  2014-05-01  731.617622   414.577666   736.219746   731.617622   731.617622
# ..        ...         ...          ...          ...          ...          ...
# 67 2019-08-01  820.483484   503.663188   820.075623   820.483461   820.483505
# 68 2019-09-01  821.919793  1210.796035  1525.848548   821.919769   821.919817
# 69 2019-10-01  823.309770   660.892753   962.383752   823.309744   823.309796
# 70 2019-11-01  824.746079  1079.855178  1401.185155   824.746052   824.746107
# 71 2019-12-01  826.136056  1094.736330  1402.035283   826.136027   826.136086
#
#     additive_terms  additive_terms_lower  additive_terms_upper      yearly  \
# 0      -190.685662           -190.685662           -190.685662 -190.685662
# 1      -276.377703           -276.377703           -276.377703 -276.377703
# 2       -22.389755            -22.389755            -22.389755  -22.389755
# 3      -100.141158           -100.141158           -100.141158 -100.141158
# 4      -160.815662           -160.815662           -160.815662 -160.815662
# ..             ...                   ...                   ...         ...
# 67     -152.742582           -152.742582           -152.742582 -152.742582
# 68      551.713042            551.713042            551.713042  551.713042
# 69      -13.792198            -13.792198            -13.792198  -13.792198
# 70      413.144741            413.144741            413.144741  413.144741
# 71      417.365653            417.365653            417.365653  417.365653
#
#     yearly_lower  yearly_upper  multiplicative_terms  \
# 0    -190.685662   -190.685662                   0.0
# 1    -276.377703   -276.377703                   0.0
# 2     -22.389755    -22.389755                   0.0
# 3    -100.141158   -100.141158                   0.0
# 4    -160.815662   -160.815662                   0.0
# ..           ...           ...                   ...
# 67   -152.742582   -152.742582                   0.0
# 68    551.713042    551.713042                   0.0
# 69    -13.792198    -13.792198                   0.0
# 70    413.144741    413.144741                   0.0
# 71    417.365653    417.365653                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                          0.0                         0.0   535.372051
# 1                          0.0                         0.0   451.116320
# 2                          0.0                         0.0   706.401580
# 3                          0.0                         0.0   630.086487
# 4                          0.0                         0.0   570.801960
# ..                         ...                         ...          ...
# 67                         0.0                         0.0   667.740901
# 68                         0.0                         0.0  1373.632835
# 69                         0.0                         0.0   809.517572
# 70                         0.0                         0.0  1237.890821
# 71                         0.0                         0.0  1243.501709
#
# [72 rows x 16 columns]

# %%
forecast_furniture.columns
# Out:
# Index(['ds', 'trend', 'yhat_lower', 'yhat_upper', 'trend_lower', 'trend_upper',
#        'additive_terms', 'additive_terms_lower', 'additive_terms_upper',
#        'yearly', 'yearly_lower', 'yearly_upper', 'multiplicative_terms',
#        'multiplicative_terms_lower', 'multiplicative_terms_upper', 'yhat'],
#       dtype='object')

# %%
forecast_furniture[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
#            ds   yhat_lower   yhat_upper         yhat
# 60 2019-01-01   532.350159   845.300625   680.605855
# 61 2019-02-01   308.985397   622.183633   471.018150
# 62 2019-03-01   695.599153  1015.150328   860.015348
# 63 2019-04-01   611.738871   919.134857   761.302342
# 64 2019-05-01   480.726019   780.812652   631.589549
# 65 2019-06-01   460.387051   772.344779   609.811049
# 66 2019-07-01   607.256809   925.407881   770.752517
# 67 2019-08-01   503.663188   820.075623   667.740901
# 68 2019-09-01  1210.796035  1525.848548  1373.632835
# 69 2019-10-01   660.892753   962.383752   809.517572
# 70 2019-11-01  1079.855178  1401.185155  1237.890821
# 71 2019-12-01  1094.736330  1402.035283  1243.501709

# %%
m_furniture.plot(forecast_furniture);
plt.title('Sales of furniture')
plt.xlabel('Years')
plt.ylabel('Sales')
# Out:
# Text(48.5, 0.5, 'Sales')

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m_furniture, forecast_furniture)
forecast_furniture.plot(x='ds',y='yhat',figsize=(12,5))

m_furniture.plot_components(forecast_furniture);

# %%
plot_components_plotly(m_furniture , forecast_furniture)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="c23c7e29-f07a-45dd-a359-fa4bcef83967" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c23c7e29-f07a-45dd-a359-fa4bcef83967")) {                    Plotly.newPlot(                        "c23c7e29-f07a-45dd-a359-fa4bcef83967",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00"],"y":[726.0577129801334,727.4940228616543,728.7913350012446,730.2276448700767,731.6176221632841,733.0539320379785,734.4439093360699,735.8802192155196,737.3165290984408,738.7065064044937,740.1428162919873,741.5327935917965,742.9691034682659,744.4054133504831,745.7027255005488,747.1390353809788,748.5290126683155,749.965322538937,751.355299833087,752.7916092991538,754.227918768334,755.617895673992,757.0542051401934,758.4441820284565,759.8804914796614,761.316800920961,762.6604452267409,764.0967546570573,765.4867315329411,766.9230409712874,768.3130178471062,769.7493272885908,771.1856367348806,772.5756136183869,774.0119230541602,775.4018999334398,776.8382093753621,778.2745188203365,779.5718305783405,781.0081400247018,782.3981169082776,783.8344263546389,785.2244032382146,786.6607126845761,788.0970221309376,789.4869990145131,790.9233084608746,792.3132853444503,793.7495947908118,795.1859042371731,796.483215995177,797.9195254415386,799.3095023251142,800.7458117714757,802.1357886550512,803.5720981014127,805.0084075477743,806.3983844313499,807.8346938777114,809.2246707612869,810.6609802076483,812.0972896540098,813.3946014120137,814.8309108583752,816.2208877419508,817.6571971883124,819.047174071888,820.4834835182495,821.919792964611,823.3097698481864,824.7460792945479,826.1360561781237],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgba(0, 114, 178, 0.2)","width":0},"mode":"lines","name":"trend_upper","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T ...

# %%
y_office_df = y_office.to_frame()
y_office_df['ds'] = y_office_df.index
y_office_df.columns = ['y','ds']
y_office_df
# Out:
#                       y         ds
# Order Date
# 2014-01-01   285.357647 2014-01-01
# 2014-02-01    63.042588 2014-02-01
# 2014-03-01   391.176318 2014-03-01
# 2014-04-01   464.794750 2014-04-01
# 2014-05-01   324.346545 2014-05-01
# 2014-06-01   588.774409 2014-06-01
# 2014-07-01   756.060400 2014-07-01
# 2014-08-01   541.879143 2014-08-01
# 2014-09-01  1015.677704 2014-09-01
# 2014-10-01   267.078815 2014-10-01
# 2014-11-01   959.372714 2014-11-01
# 2014-12-01   692.556231 2014-12-01
# 2015-01-01   129.198571 2015-01-01
# 2015-02-01   335.504188 2015-02-01
# 2015-03-01   690.545522 2015-03-01
# 2015-04-01   502.342320 2015-04-01
# 2015-05-01   364.549440 2015-05-01
# 2015-06-01   560.407737 2015-06-01
# 2015-07-01   205.214739 2015-07-01
# 2015-08-01   558.814667 2015-08-01
# 2015-09-01   772.230680 2015-09-01
# 2015-10-01   361.392083 2015-10-01
# 2015-11-01   757.790357 2015-11-01
# 2015-12-01   540.055800 2015-12-01
# 2016-01-01   331.230125 2016-01-01
# 2016-02-01   357.597368 2016-02-01
# 2016-03-01   693.877240 2016-03-01
# 2016-04-01   462.932478 2016-04-01
# 2016-05-01   449.489724 2016-05-01
# 2016-06-01   436.072400 2016-06-01
# 2016-07-01   587.474727 2016-07-01
# 2016-08-01   344.605385 2016-08-01
# 2016-09-01   830.847786 2016-09-01
# 2016-10-01   678.408083 2016-10-01
# 2016-11-01   787.972231 2016-11-01
# 2016-12-01  1357.055929 2016-12-01
# 2017-01-01   967.013136 2017-01-01
# 2017-02-01   389.882737 2017-02-01
# 2017-03-01   538.899481 2017-03-01
# 2017-04-01   558.229296 2017-04-01
# 2017-05-01   508.776444 2017-05-01
# 2017-06-01   650.463038 2017-06-01
# 2017-07-01   393.902615 2017-07-01
# 2017-08-01  1156.148154 2017-08-01
# 2017-09-01  1139.137250 2017-09-01
# 2017-10-01   886.045846 2017-10-01
# 2017-11-01  1124.012036 2017-11-01
# 2017-12-01  1049.549724 2017-12-01

# %%
m_office = Prophet()

m_office.fit(y_office_df)

future_office = m_office.make_future_dataframe(periods=24,freq='MS')

future_office
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#            ds
# 0  2014-01-01
# 1  2014-02-01
# 2  2014-03-01
# 3  2014-04-01
# 4  2014-05-01
# ..        ...
# 67 2019-08-01
# 68 2019-09-01
# 69 2019-10-01
# 70 2019-11-01
# 71 2019-12-01
#
# [72 rows x 1 columns]

# %%
forecast_office = m_office.predict(future_office)
forecast_office
# Out:
#            ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0  2014-01-01   487.530759   148.254967   539.799845   487.530759
# 1  2014-02-01   494.918445   -94.982398   302.601142   494.918445
# 2  2014-03-01   501.591193   275.437698   665.271480   501.591193
# 3  2014-04-01   508.978878   172.904169   577.633623   508.978878
# 4  2014-05-01   516.128251    55.950344   451.092404   516.128251
# ..        ...          ...          ...          ...          ...
# 67 2019-08-01   973.646513   833.132081  1222.409729   973.618640
# 68 2019-09-01   981.044899  1124.429265  1516.651585   981.014776
# 69 2019-10-01   988.204628   601.017867   976.345425   988.171936
# 70 2019-11-01   995.603015  1200.802945  1607.238170   995.568147
# 71 2019-12-01  1002.762744   814.290900  1235.194590  1002.725913
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    487.530759     -140.040481           -140.040481           -140.040481
# 1    494.918445     -385.678283           -385.678283           -385.678283
# 2    501.591193      -31.379844            -31.379844            -31.379844
# 3    508.978878     -134.291690           -134.291690           -134.291690
# 4    516.128251     -263.821569           -263.821569           -263.821569
# ..          ...             ...                   ...                   ...
# 67   973.673885       43.876319             43.876319             43.876319
# 68   981.074513      338.281914            338.281914            338.281914
# 69   988.236760     -188.232901           -188.232901           -188.232901
# 70   995.637501      400.624464            400.624464            400.624464
# 71  1002.799350       22.996056             22.996056             22.996056
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0  -140.040481   -140.040481   -140.040481                   0.0
# 1  -385.678283   -385.678283   -385.678283                   0.0
# 2   -31.379844    -31.379844    -31.379844                   0.0
# 3  -134.291690   -134.291690   -134.291690                   0.0
# 4  -263.821569   -263.821569   -263.821569                   0.0
# ..         ...           ...           ...                   ...
# 67   43.876319     43.876319     43.876319                   0.0
# 68  338.281914    338.281914    338.281914                   0.0
# 69 -188.232901   -188.232901   -188.232901                   0.0
# 70  400.624464    400.624464    400.624464                   0.0
# 71   22.996056     22.996056     22.996056                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                          0.0                         0.0   347.490278
# 1                          0.0                         0.0   109.240162
# 2                          0.0                         0.0   470.211349
# 3                          0.0                         0.0   374.687188
# 4                          0.0                         0.0   252.306682
# ..                         ...                         ...          ...
# 67                         0.0                         0.0  1017.522832
# 68                         0.0                         0.0  1319.326813
# 69                         0.0                         0.0   799.971727
# 70                         0.0                         0.0  1396.227478
# 71                         0.0                         0.0  1025.758800
#
# [72 rows x 16 columns]

# %%
forecast_office.columns

forecast_office[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
#            ds   yhat_lower   yhat_upper         yhat
# 60 2019-01-01   494.423670   881.686798   680.667168
# 61 2019-02-01   430.257456   840.537628   635.972532
# 62 2019-03-01   761.935044  1139.736335   946.732949
# 63 2019-04-01   620.823805  1016.887613   822.147677
# 64 2019-05-01   437.006711   813.403100   628.940592
# 65 2019-06-01   679.924637  1076.271178   884.346368
# 66 2019-07-01   489.566875   871.917095   677.208351
# 67 2019-08-01   833.132081  1222.409729  1017.522832
# 68 2019-09-01  1124.429265  1516.651585  1319.326813
# 69 2019-10-01   601.017867   976.345425   799.971727
# 70 2019-11-01  1200.802945  1607.238170  1396.227478
# 71 2019-12-01   814.290900  1235.194590  1025.758800

# %%
m_office.plot(forecast_office)
plt.title('Sales of office items')
plt.xlabel('Years')
plt.ylabel('Sales')
# Out:
# Text(48.5, 0.5, 'Sales')

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m_office, forecast_office)
forecast_office.plot(x='ds',y='yhat',figsize=(12,5))

m_office.plot_components(forecast_office);

# %%
plot_components_plotly(m_office, forecast_office)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="73a85033-a770-44d8-bd86-27f3a9aad1ff" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73a85033-a770-44d8-bd86-27f3a9aad1ff")) {                    Plotly.newPlot(                        "73a85033-a770-44d8-bd86-27f3a9aad1ff",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00"],"y":[487.5307593559924,494.918444615048,501.5911926012193,508.9788778716231,516.1282507114032,523.5159359681822,530.6653087973233,538.0529940538071,545.4406792994126,552.5900521177407,559.9777373713675,567.1271101948826,574.5147954458481,581.902480707668,588.5752286921277,595.9629139606366,603.1122868078975,610.4999720888575,617.6493449413995,625.0370302574647,632.4261373093846,639.576886069307,646.9659931374298,654.1167419203821,661.5058489960995,668.8949560923014,675.8102694487167,683.2025009676433,690.3599061077274,697.7582926224675,704.9180215076996,712.3164080243945,719.7147945466273,726.8745234391109,734.2729099584498,741.4326388412626,748.8310253535024,756.2294118746519,762.9118255142465,770.3102120437976,777.4699409433633,784.8683274729143,792.02805637248,799.4264429020312,806.8248294315823,813.9845583311479,821.3829448606989,828.5426737602646,835.9410602898158,843.339446819367,850.0218604589613,857.4202469885125,864.5799758880781,871.9783624176292,879.1380913171948,886.5364778467459,893.9348643762971,901.0945932758627,908.4929798054138,915.6527087049793,923.0510952345305,930.4494817640817,937.1318954036763,944.5302819332275,951.690010832793,959.0883973623442,966.2481262619098,973.6465127914609,981.044899321012,988.2046282205775,995.6030147501288,1002.7627436496944],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgba(0, 114, 178, 0.2)","width":0},"mode":"lines","name":"trend_upper","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01 ...

# %%
y_technology_df = y_technology.to_frame()
y_technology_df['ds'] = y_technology_df.index
y_technology_df.columns = ['y','ds']
y_technology_df
# Out:
#                       y         ds
# Order Date
# 2014-01-01   449.041429 2014-01-01
# 2014-02-01   229.787143 2014-02-01
# 2014-03-01  2031.948375 2014-03-01
# 2014-04-01   613.028933 2014-04-01
# 2014-05-01   564.698588 2014-05-01
# 2014-06-01   766.905909 2014-06-01
# 2014-07-01   533.608933 2014-07-01
# 2014-08-01   708.435385 2014-08-01
# 2014-09-01  2035.838133 2014-09-01
# 2014-10-01   596.900900 2014-10-01
# 2014-11-01  1208.056320 2014-11-01
# 2014-12-01  1160.732889 2014-12-01
# 2015-01-01   925.070800 2015-01-01
# 2015-02-01   431.121250 2015-02-01
# 2015-03-01   574.662333 2015-03-01
# 2015-04-01   697.559500 2015-04-01
# 2015-05-01   831.642857 2015-05-01
# 2015-06-01   429.024400 2015-06-01
# 2015-07-01   691.397733 2015-07-01
# 2015-08-01  1108.902286 2015-08-01
# 2015-09-01   950.856400 2015-09-01
# 2015-10-01   594.716111 2015-10-01
# 2015-11-01  1037.982652 2015-11-01
# 2015-12-01  1619.637636 2015-12-01
# 2016-01-01   374.671067 2016-01-01
# 2016-02-01  1225.891400 2016-02-01
# 2016-03-01  1135.150105 2016-03-01
# 2016-04-01   875.911882 2016-04-01
# 2016-05-01  1601.816167 2016-05-01
# 2016-06-01  1023.259500 2016-06-01
# 2016-07-01   829.312500 2016-07-01
# 2016-08-01   483.620100 2016-08-01
# 2016-09-01  1144.170300 2016-09-01
# 2016-10-01  1970.835875 2016-10-01
# 2016-11-01  1085.642360 2016-11-01
# 2016-12-01   970.554870 2016-12-01
# 2017-01-01  1195.218071 2017-01-01
# 2017-02-01   430.501714 2017-02-01
# 2017-03-01  1392.859250 2017-03-01
# 2017-04-01   825.559133 2017-04-01
# 2017-05-01   678.329400 2017-05-01
# 2017-06-01   853.055000 2017-06-01
# 2017-07-01  1054.996636 2017-07-01
# 2017-08-01   978.842333 2017-08-01
# 2017-09-01  1077.704120 2017-09-01
# 2017-10-01  1493.439227 2017-10-01
# 2017-11-01  1996.750920 2017-11-01
# 2017-12-01   955.865652 2017-12-01

# %%
m_technology = Prophet()

m_technology.fit(y_technology_df)

future_technology = m_technology.make_future_dataframe(periods=24,freq='MS')

future_technology
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
#            ds
# 0  2014-01-01
# 1  2014-02-01
# 2  2014-03-01
# 3  2014-04-01
# 4  2014-05-01
# ..        ...
# 67 2019-08-01
# 68 2019-09-01
# 69 2019-10-01
# 70 2019-11-01
# 71 2019-12-01
#
# [72 rows x 1 columns]

# %%
forecast_technology = m_technology.predict(future_technology)
forecast_technology
# Out:
#            ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 0  2014-01-01   952.355848   382.637773  1105.246446   952.355848
# 1  2014-02-01   958.476983   -43.143640   694.456845   958.476983
# 2  2014-03-01   964.005750   775.684448  1524.412920   964.005750
# 3  2014-04-01   970.126885   287.462432  1001.097879   970.126885
# 4  2014-05-01   976.050565   390.883590  1103.051775   976.050565
# ..        ...          ...          ...          ...          ...
# 67 2019-08-01  1354.771259  1128.237556  1858.564323  1354.771210
# 68 2019-09-01  1360.892397  1381.314787  2128.728663  1360.892344
# 69 2019-10-01  1366.816079   435.427105  1164.134389  1366.816022
# 70 2019-11-01  1372.937217  1164.227738  1871.336530  1372.937156
# 71 2019-12-01  1378.860899  1419.222918  2127.084694  1378.860835
#
#     trend_upper  additive_terms  additive_terms_lower  additive_terms_upper  \
# 0    952.355848     -220.575922           -220.575922           -220.575922
# 1    958.476983     -613.862112           -613.862112           -613.862112
# 2    964.005750      181.810553            181.810553            181.810553
# 3    970.126885     -328.523260           -328.523260           -328.523260
# 4    976.050565     -237.352937           -237.352937           -237.352937
# ..          ...             ...                   ...                   ...
# 67  1354.771305      135.984662            135.984662            135.984662
# 68  1360.892447      399.261873            399.261873            399.261873
# 69  1366.816133     -585.314418           -585.314418           -585.314418
# 70  1372.937276      150.401115            150.401115            150.401115
# 71  1378.860962      411.778084            411.778084            411.778084
#
#         yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0  -220.575922   -220.575922   -220.575922                   0.0
# 1  -613.862112   -613.862112   -613.862112                   0.0
# 2   181.810553    181.810553    181.810553                   0.0
# 3  -328.523260   -328.523260   -328.523260                   0.0
# 4  -237.352937   -237.352937   -237.352937                   0.0
# ..         ...           ...           ...                   ...
# 67  135.984662    135.984662    135.984662                   0.0
# 68  399.261873    399.261873    399.261873                   0.0
# 69 -585.314418   -585.314418   -585.314418                   0.0
# 70  150.401115    150.401115    150.401115                   0.0
# 71  411.778084    411.778084    411.778084                   0.0
#
#     multiplicative_terms_lower  multiplicative_terms_upper         yhat
# 0                          0.0                         0.0   731.779926
# 1                          0.0                         0.0   344.614871
# 2                          0.0                         0.0  1145.816303
# 3                          0.0                         0.0   641.603626
# 4                          0.0                         0.0   738.697628
# ..                         ...                         ...          ...
# 67                         0.0                         0.0  1490.755922
# 68                         0.0                         0.0  1760.154270
# 69                         0.0                         0.0   781.501661
# 70                         0.0                         0.0  1523.338332
# 71                         0.0                         0.0  1790.638983
#
# [72 rows x 16 columns]

# %%
forecast_technology.columns

forecast_technology[['ds','yhat_lower', 'yhat_upper','yhat']].tail(12)
# Out:
#            ds   yhat_lower   yhat_upper         yhat
# 60 2019-01-01   524.716471  1250.825639   883.346452
# 61 2019-02-01   591.998510  1291.961964   955.920525
# 62 2019-03-01  1093.256400  1796.299614  1438.858819
# 63 2019-04-01   626.295701  1345.523148   991.798219
# 64 2019-05-01   584.724243  1292.715049   955.687693
# 65 2019-06-01   582.268393  1285.288020   924.219609
# 66 2019-07-01   720.634150  1451.038624  1083.824250
# 67 2019-08-01  1128.237556  1858.564323  1490.755922
# 68 2019-09-01  1381.314787  2128.728663  1760.154270
# 69 2019-10-01   435.427105  1164.134389   781.501661
# 70 2019-11-01  1164.227738  1871.336530  1523.338332
# 71 2019-12-01  1419.222918  2127.084694  1790.638983

# %%
m_technology.plot(forecast_technology);
plt.title('Sales of technology')
plt.xlabel('Years')
plt.ylabel('Sales')
# Out:
# Text(48.5, 0.5, 'Sales')

# %%
from prophet.plot import plot_plotly, plot_components_plotly

plot_plotly(m_technology, forecast_technology)
forecast_technology.plot(x='ds',y='yhat',figsize=(12,5))
m_technology.plot_components(forecast_technology);

# %%
plot_components_plotly(m_technology, forecast_technology)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7f54bc24-0433-4020-8983-c6fa7e714256" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f54bc24-0433-4020-8983-c6fa7e714256")) {                    Plotly.newPlot(                        "7f54bc24-0433-4020-8983-c6fa7e714256",                        [{"line":{"color":"#0072B2","width":2},"mode":"lines","name":"trend","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:00","2017-07-01T00:00:00","2017-08-01T00:00:00","2017-09-01T00:00:00","2017-10-01T00:00:00","2017-11-01T00:00:00","2017-12-01T00:00:00","2018-01-01T00:00:00","2018-02-01T00:00:00","2018-03-01T00:00:00","2018-04-01T00:00:00","2018-05-01T00:00:00","2018-06-01T00:00:00","2018-07-01T00:00:00","2018-08-01T00:00:00","2018-09-01T00:00:00","2018-10-01T00:00:00","2018-11-01T00:00:00","2018-12-01T00:00:00","2019-01-01T00:00:00","2019-02-01T00:00:00","2019-03-01T00:00:00","2019-04-01T00:00:00","2019-05-01T00:00:00","2019-06-01T00:00:00","2019-07-01T00:00:00","2019-08-01T00:00:00","2019-09-01T00:00:00","2019-10-01T00:00:00","2019-11-01T00:00:00","2019-12-01T00:00:00"],"y":[952.3558480997672,958.4769829512695,964.0057502533118,970.1268854805728,976.0505650524335,982.1717008613999,988.0953806765286,994.2165164970587,1000.33765267364,1006.2613328445253,1012.3824685299551,1018.3061483341465,1024.4272841318111,1030.548419758057,1036.0771874300856,1042.1983230669741,1048.1220024879603,1054.243138504316,1060.166818520144,1066.287955334666,1072.4090928490757,1078.3327743146335,1084.4539123549898,1090.3775939658167,1096.4987316303377,1102.619869517676,1108.346094909784,1114.4672323978996,1120.3909139654859,1126.512051483927,1132.4357329533864,1138.5568700767394,1144.6780077587969,1150.6016893865944,1156.7228274671277,1162.6465094880484,1168.767647576333,1174.888785941099,1180.4175557050664,1186.5386936580308,1192.462375547996,1198.5835135009602,1204.5071953909255,1210.6283333438898,1216.7494712968537,1222.673153186819,1228.7942911397834,1234.7179730297485,1240.8391109827128,1246.960248935677,1252.4890186996445,1258.6101566526088,1264.5338385425741,1270.6549764955382,1276.5786583855036,1282.6997963384679,1288.8209342914317,1294.744616181397,1300.8657541343614,1306.7894360243265,1312.9105739772908,1319.0317119302551,1324.5604816942225,1330.6816196471868,1336.6053015371522,1342.7264394901163,1348.6501213800816,1354.771259333046,1360.8923972860098,1366.8160791759753,1372.9372171289394,1378.8608990189045],"type":"scatter","xaxis":"x","yaxis":"y"},{"line":{"color":"rgba(0, 114, 178, 0.2)","width":0},"mode":"lines","name":"trend_upper","x":["2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00", ...
